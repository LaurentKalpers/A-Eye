# %%
import numpy as np
import cv2
import matplotlib as mpimp
import os
import winsound
import base64
import glob
import json
import requests

# If you are using a Jupyter notebook, uncomment the following line.
# %matplotlib inline
import matplotlib.pyplot as plt
from PIL import Image
from io import BytesIO

# %%
# Subscretion key to access azure services
subscription_key = "df3821039a5f4f5a885d487b4016051f"
assert subscription_key

# %%
#Function that process pictures to locate different objects
def process(img):
    vision_base_url = "https://eastus2.api.cognitive.microsoft.com/vision/v2.0/"

    analyze_url = vision_base_url + "analyze"

    # Set image_path to the local path of an image that you want to analyze.
    image_path = "pic1.jpg"

    # Read the image into a byte array
    image_data = open(image_path, "rb").read()
    headers = {'Ocp-Apim-Subscription-Key': subscription_key,
               'Content-Type': 'application/octet-stream'}
    # params     = {'visualFeatures': 'Categories,Description,Color,Objects'}
    params = {'visualFeatures': 'Objects'}
    response = requests.post(
        analyze_url, headers=headers, params=params, data=image_data)
    print(response)
    response.raise_for_status()

    # The 'analysis' object contains various fields that describe the image. The most
    # relevant caption for the image is obtained from the 'description' property.
    analysis = response.json()
    print(analysis)

    y = json.dumps(analysis)
    y1 = json.loads(y)
    return y1

# %%
cap = cv2.VideoCapture(0)

ret, img = cap.read()

cv2.imwrite('pic1.jpg', img)
y1 = process(img)

while (True):
    ret, img = cap.read()
    cv2.imwrite('pic1.jpg', img)

    y2=process(img)

    for object1 in y1['objects']:
            for object2 in y2['objects']:
                if (object1['object'] == object2['object']):
                        print((object1['rectangle']['w'] * object1['rectangle']['h']) / (object2['rectangle']['w'] * object2['rectangle']['h']))
                if(object1['object']== object2['object'] and
                        (object1['rectangle']['w'] * object1['rectangle']['h'])/(object2['rectangle']['w'] * object2['rectangle']['h']) < 0.9):
                    winsound.Beep(440, 1000)

    y1 = y2
# Out:
# <Response [200]>
# {'objects': [{'rectangle': {'x': 106, 'y': 112, 'w': 516, 'h': 368}, 'object': 'person', 'confidence': 0.592}], 'requestId': 'f7f629bd-6013-4235-ad27-ad883b365a1c', 'metadata': {'width': 640, 'height': 480, 'format': 'Jpeg'}}
# <Response [200]>
# {'objects': [{'rectangle': {'x': 340, 'y': 205, 'w': 131, 'h': 45}, 'object': 'Sunglasses', 'confidence': 0.539, 'parent': {'object': 'Glasses', 'confidence': 0.793, 'parent': {'object': 'Personal care', 'confidence': 0.794}}}, {'rectangle': {'x': 148, 'y': 131, 'w': 444, 'h': 338}, 'object': 'person', 'confidence': 0.834}], 'requestId': '1f5789fc-5e83-4d78-a016-94996e8cb080', 'metadata': {'width': 640, 'height': 480, 'format': 'Jpeg'}}
# 1.2653126499280345
# <Response [200]>
# {'objects': [{'rectangle': {'x': 161, 'y': 145, 'w': 209, 'h': 72}, 'object': 'Glasses', 'confidence': 0.84, 'parent': {'object': 'Personal care', 'confidence': 0.841}}, {'rectangle': {'x': 8, 'y': 18, 'w': 481, 'h': 462}, 'object': 'person', 'confidence': 0.886}], 'requestId': 'f1f5a4a3-d959-4e4c-92c4-922a85d749a1', 'metadata': {'width': 640, 'height': 480, 'format': 'Jpeg'}}
# 0.6753246753246753
# <Response [200]>
# {'objects': [{'rectangle': {'x': 209, 'y': 161, 'w': 188, 'h': 67}, 'object': 'Glasses', 'confidence': 0.851, 'parent': {'object': 'Personal care', 'confidence': 0.853}}, {'rectangle': {'x': 14, 'y': 45, 'w': 519, 'h': 435}, 'object': 'person', 'confidence': 0.835}], 'requestId': 'c4533cfa-7ae0-4ded-a80d-e29ef517f525', 'metadata': {'width': 640, 'height': 480, 'format': 'Jpeg'}}
# 1.194664973007304
# 0.9843066905853431
# <Response [200]>
# {'objects': [{'rectangle': {'x': 222, 'y': 151, 'w': 200, 'h': 77}, 'object': 'Glasses', 'confidence': 0.805, 'parent': {'object': 'Personal care', 'confidence': 0.806}}, {'rectangle': {'x': 72, 'y': 18, 'w': 500, 'h': 462}, 'object': 'person', 'confidence': 0.754}], 'requestId': 'd67ffffa-9111-4576-a424-22744dc84f7a', 'metadata': {'width': 640, 'height': 480, 'format': 'Jpeg'}}
# 0.8179220779220779
# 0.9773376623376623
# <Response [200]>
# {'objects': [{'rectangle': {'x': 266, 'y': 153, 'w': 175, 'h': 66}, 'object': 'Glasses', 'confidence': 0.798, 'parent': {'object': 'Personal care', 'confidence': 0.8}}, {'rectangle': {'x': 74, 'y': 41, 'w': 498, 'h': 438}, 'object': 'person', 'confidence': 0.844}], 'requestId': '3d840bf7-7378-4c2d-86a2-0e5755897b7d', 'metadata': {'width': 640, 'height': 480, 'format': 'Jpeg'}}
# 1.3333333333333333
# 1.0590306431204268
# <Response [200]>
# {'objects': [{'rectangle': {'x': 309, 'y': 148, 'w': 179, 'h': 67}, 'object': 'Glasses', 'confidence': 0.821, 'parent': {'object': 'Personal care', 'confidence': 0.822}}, {'rectangle': {'x': 156, 'y': 34, 'w': 431, 'h': 439}, 'object': 'person', 'confidence': 0.909}], 'requestId': '60324580-32c8-4198-9b68-7bc0931d56f2', 'metadata': {'width': 640, 'height': 480, 'format': 'Jpeg'}}
# 0.9630617860418578
# 1.152820426089668
# <Response [200]>
# {'objects': [{'rectangle': {'x': 237, 'y': 147, 'w': 262, 'h': 92}, 'object': 'Glasses', 'confidence': 0.818, 'parent': {'object': 'Personal care', 'confidence': 0.819}}, {'rectangle': {'x': 108, 'y': 10, 'w': 509, 'h': 470}, 'object': 'person', 'confidence': 0.698}], 'requestId': '6cdd90bf-48f6-4320-80ce-23bbe24ca148', 'metadata': {'width': 640, 'height': 480, 'format': 'Jpeg'}}
# 0.4975522734815798
# 0.7909083308949546
# <Response [200]>
# {'objects': [{'rectangle': {'x': 229, 'y': 207, 'w': 277, 'h': 97}, 'object': 'Glasses', 'confidence': 0.822, 'parent': {'object': 'Personal care', 'confidence': 0.823}}, {'rectangle': {'x': 9, 'y': 19, 'w': 526, 'h': 457}, 'object': 'person', 'confidence': 0.709}], 'requestId': '678ee0d9-390d-437f-912b-898b40e84157', 'metadata': {'width': 640, 'height': 480, 'format': 'Jpeg'}}
# 0.8970933045517139
# 0.9952076278589911
# <Response [200]>
# {'objects': [{'rectangle': {'x': 212, 'y': 240, 'w': 367, 'h': 154}, 'object': 'Glasses', 'confidence': 0.756, 'parent': {'object': 'Personal care', 'confidence': 0.771}}, {'rectangle': {'x': 114, 'y': 15, 'w': 514, 'h': 465}, 'object': 'person', 'confidence': 0.809}], 'requestId': '23bec5da-f8d0-4870-be51-2d95fb5bfa8a', 'metadata': {'width': 640, 'height': 480, 'format': 'Jpeg'}}
# 0.47540606532432145
# 1.0057403455922347
# <Response [200]>
# {'objects': [{'rectangle': {'x': 188, 'y': 219, 'w': 199, 'h': 71}, 'object': 'Glasses', 'confidence': 0.809, 'parent': {'object': 'Personal care', 'confidence': 0.81}}, {'rectangle': {'x': 15, 'y': 64, 'w': 511, 'h': 414}, 'object': 'person', 'confidence': 0.91}], 'requestId': '868f4822-d1a3-46b2-bb15-f6bd5326d6e4', 'metadata': {'width': 640, 'height': 480, 'format': 'Jpeg'}}
# 4.000141552834595
# 1.1297824668878869
# <Response [200]>
# {'objects': [{'rectangle': {'x': 252, 'y': 242, 'w': 160, 'h': 62}, 'object': 'Glasses', 'confidence': 0.823, 'parent': {'object': 'Personal care', 'confidence': 0.824}}, {'rectangle': {'x': 95, 'y': 142, 'w': 436, 'h': 329}, 'object': 'person', 'confidence': 0.878}], 'requestId': '31b376b0-cbc1-4e07-bca8-ea9983b304e7', 'metadata': {'width': 640, 'height': 480, 'format': 'Jpeg'}}
# 1.4242943548387097
# 1.4748194417333593
# <Response [200]>
# {'objects': [{'rectangle': {'x': 200, 'y': 239, 'w': 166, 'h': 64}, 'object': 'Glasses', 'confidence': 0.842, 'parent': {'object': 'Personal care', 'confidence': 0.843}}, {'rectangle': {'x': 22, 'y': 116, 'w': 504, 'h': 354}, 'object': 'person', 'confidence': 0.878}], 'requestId': '90383185-30bd-4fee-95e0-5a82255d9a46', 'metadata': {'width': 640, 'height': 480, 'format': 'Jpeg'}}
# 0.9337349397590361
# 0.8039861895794099
# <Response [200]>
# {'objects': [{'rectangle': {'x': 191, 'y': 238, 'w': 168, 'h': 62}, 'object': 'Glasses', 'confidence': 0.841, 'parent': {'object': 'Personal care', 'confidence': 0.842}}, {'rectangle': {'x': 18, 'y': 116, 'w': 500, 'h': 358}, 'object': 'person', 'confidence': 0.88}], 'requestId': 'f3e0569d-d02b-4bfd-b0e1-fec8d9c39612', 'metadata': {'width': 640, 'height': 480, 'format': 'Jpeg'}}
# 1.0199692780337941
# 0.9967374301675977
# <Response [200]>
# {'objects': [{'rectangle': {'x': 189, 'y': 238, 'w': 167, 'h': 63}, 'object': 'Glasses', 'confidence': 0.845, 'parent': {'object': 'Personal care', 'confidence': 0.846}}, {'rectangle': {'x': 17, 'y': 115, 'w': 502, 'h': 359}, 'object': 'person', 'confidence': 0.876}], 'requestId': '4df1122d-3cbc-4499-a275-68fa12550900', 'metadata': {'width': 640, 'height': 480, 'format': 'Jpeg'}}
# 0.9900199600798403
# 0.9932415186052448
# <Response [200]>
# {'objects': [{'rectangle': {'x': 190, 'y': 236, 'w': 168, 'h': 64}, 'object': 'Glasses', 'confidence': 0.836, 'parent': {'object': 'Personal care', 'confidence': 0.837}}, {'rectangle': {'x': 42, 'y': 135, 'w': 452, 'h': 328}, 'object': 'person', 'confidence': 0.889}], 'requestId': '2aec6f38-f16c-4485-922a-b6bf93919e1a', 'metadata': {'width': 640, 'height': 480, 'format': 'Jpeg'}}
# 0.978515625
# 1.2155865529894236
# <Response [200]>
# {'objects': [{'rectangle': {'x': 85, 'y': 167, 'w': 269, 'h': 90}, 'object': 'Glasses', 'confidence': 0.862, 'parent': {'object': 'Personal care', 'confidence': 0.863}}, {'rectangle': {'x': 5, 'y': 7, 'w': 535, 'h': 473}, 'object': 'person', 'confidence': 0.871}], 'requestId': '56545887-e79b-4125-911c-268606476000', 'metadata': {'width': 640, 'height': 480, 'format': 'Jpeg'}}
# 0.44411400247831473
# 0.5858647329631899
# <Response [200]>
# {'objects': [{'rectangle': {'x': 145, 'y': 230, 'w': 256, 'h': 86}, 'object': 'Glasses', 'confidence': 0.846, 'parent': {'object': 'Personal care', 'confidence': 0.847}}, {'rectangle': {'x': 3, 'y': 31, 'w': 532, 'h': 449}, 'object': 'person', 'confidence': 0.9}], 'requestId': 'e7f7cc83-7dd2-4641-bd52-83bf9e5f2d4b', 'metadata': {'width': 640, 'height': 480, 'format': 'Jpeg'}}
# 1.099654796511628
# 1.0593926352629905
# <Response [200]>
# {'objects': [{'rectangle': {'x': 147, 'y': 196, 'w': 287, 'h': 83}, 'object': 'Glasses', 'confidence': 0.874, 'parent': {'object': 'Personal care', 'confidence': 0.876}}, {'rectangle': {'x': 7, 'y': 17, 'w': 536, 'h': 461}, 'object': 'person', 'confidence': 0.847}], 'requestId': '8cbd9e70-1b41-4722-88f0-946f1d08614d', 'metadata': {'width': 640, 'height': 480, 'format': 'Jpeg'}}
# 0.9242265228160027
# 0.9667012011525885
# <Response [200]>
# {'objects': [{'rectangle': {'x': 155, 'y': 205, 'w': 280, 'h': 95}, 'object': 'Glasses', 'confidence': 0.858, 'parent': {'object': 'Personal care', 'confidence': 0.859}}, {'rectangle': {'x': 9, 'y': 10, 'w': 535, 'h': 470}, 'object': 'person', 'confidence': 0.822}], 'requestId': 'b8af4089-c9fa-4bc9-a5a0-d60ecad7cc1c', 'metadata': {'width': 640, 'height': 480, 'format': 'Jpeg'}}
# 0.8955263157894737
# 0.9826844303042355
# <Response [200]>
# {'objects': [{'rectangle': {'x': 267, 'y': 274, 'w': 92, 'h': 27}, 'object': 'Glasses', 'confidence': 0.737, 'parent': {'object': 'Personal care', 'confidence': 0.737}}, {'rectangle': {'x': 159, 'y': 208, 'w': 299, 'h': 270}, 'object': 'person', 'confidence': 0.889}], 'requestId': '168e7132-53b1-4451-9c8c-d07150a0d072', 'metadata': {'width': 640, 'height': 480, 'format': 'Jpeg'}}
# 10.7085346215781
# 3.1147033320946362
# <Response [200]>
# {'objects': [{'rectangle': {'x': 245, 'y': 270, 'w': 99, 'h': 30}, 'object': 'Sunglasses', 'confidence': 0.518, 'parent': {'object': 'Glasses', 'confidence': 0.796, 'parent': {'object': 'Personal care', 'confidence': 0.796}}}, {'rectangle': {'x': 134, 'y': 205, 'w': 300, 'h': 273}, 'object': 'person', 'confidence': 0.891}], 'requestId': 'f3b48aa8-1690-480a-9991-a92a8db297ac', 'metadata': {'width': 640, 'height': 480, 'format': 'Jpeg'}}
# 0.9857142857142858
# <Response [200]>
# {'objects': [{'rectangle': {'x': 195, 'y': 133, 'w': 216, 'h': 76}, 'object': 'Glasses', 'confidence': 0.792, 'parent': {'object': 'Personal care', 'confidence': 0.794}}, {'rectangle': {'x': 14, 'y': 12, 'w': 526, 'h': 467}, 'object': 'person', 'confidence': 0.867}], 'requestId': '9313dc8d-f428-4a34-9583-3c953c14885b', 'metadata': {'width': 640, 'height': 480, 'format': 'Jpeg'}}
# 0.3334120386578842
# <Response [200]>
# {'objects': [{'rectangle': {'x': 131, 'y': 271, 'w': 289, 'h': 96}, 'object': 'Glasses', 'confidence': 0.817, 'parent': {'object': 'Personal care', 'confidence': 0.822}}, {'rectangle': {'x': 12, 'y': 31, 'w': 524, 'h': 445}, 'object': 'person', 'confidence': 0.867}], 'requestId': '439e6b25-4b3a-47ef-ab1d-d538fcd83352', 'metadata': {'width': 640, 'height': 480, 'format': 'Jpeg'}}
# 0.5916955017301038
# 1.053443691568745
# <Response [200]>
# {'objects': [{'rectangle': {'x': 196, 'y': 150, 'w': 218, 'h': 78}, 'object': 'Glasses', 'confidence': 0.82, 'parent': {'object': 'Personal care', 'confidence': 0.821}}, {'rectangle': {'x': 13, 'y': 17, 'w': 518, 'h': 463}, 'object': 'person', 'confidence': 0.881}], 'requestId': 'f5214649-6dbb-40ee-af47-0218c7ae6aed', 'metadata': {'width': 640, 'height': 480, 'format': 'Jpeg'}}
# 1.6316160903316868
# 0.9722558102687693
# <Response [200]>
# {'objects': [{'rectangle': {'x': 197, 'y': 152, 'w': 218, 'h': 77}, 'object': 'Glasses', 'confidence': 0.833, 'parent': {'object': 'Personal care', 'confidence': 0.835}}, {'rectangle': {'x': 13, 'y': 17, 'w': 518, 'h': 463}, 'object': 'person', 'confidence': 0.877}], 'requestId': 'c2d09f38-6f2c-470d-ad64-3865ccaaa6ec', 'metadata': {'width': 640, 'height': 480, 'format': 'Jpeg'}}
# 1.0129870129870129
# 1.0
# <Response [200]>
# {'objects': [{'rectangle': {'x': 198, 'y': 152, 'w': 217, 'h': 78}, 'object': 'Glasses', 'confidence': 0.829, 'parent': {'object': 'Personal care', 'confidence': 0.831}}, {'rectangle': {'x': 12, 'y': 19, 'w': 520, 'h': 461}, 'object': 'person', 'confidence': 0.874}], 'requestId': '913f7ed5-a2f8-445f-8dee-109f0069f095', 'metadata': {'width': 640, 'height': 480, 'format': 'Jpeg'}}
# 0.9917287014061208
# 1.0004755548139497
# <Response [200]>
# {'objects': [{'rectangle': {'x': 199, 'y': 152, 'w': 216, 'h': 79}, 'object': 'Glasses', 'confidence': 0.839, 'parent': {'object': 'Personal care', 'confidence': 0.84}}, {'rectangle': {'x': 12, 'y': 16, 'w': 520, 'h': 464}, 'object': 'person', 'confidence': 0.872}], 'requestId': '77ad04a7-5d2b-4fc5-9c6b-5edd385acbaf', 'metadata': {'width': 640, 'height': 480, 'format': 'Jpeg'}}
# 0.9919127988748242
# 0.9935344827586207
# <Response [200]>
# {'objects': [{'rectangle': {'x': 202, 'y': 154, 'w': 212, 'h': 76}, 'object': 'Glasses', 'confidence': 0.844, 'parent': {'object': 'Personal care', 'confidence': 0.845}}, {'rectangle': {'x': 11, 'y': 16, 'w': 520, 'h': 464}, 'object': 'person', 'confidence': 0.874}], 'requestId': 'fffa7cb2-944a-4aa2-9491-b1c80ee2b8b3', 'metadata': {'width': 640, 'height': 480, 'format': 'Jpeg'}}
# 1.0590863952333665
# 1.0
# <Response [200]>
# {'objects': [{'rectangle': {'x': 200, 'y': 154, 'w': 213, 'h': 77}, 'object': 'Glasses', 'confidence': 0.848, 'parent': {'object': 'Personal care', 'confidence': 0.85}}, {'rectangle': {'x': 14, 'y': 18, 'w': 519, 'h': 462}, 'object': 'person', 'confidence': 0.874}], 'requestId': '2a48587f-db11-4931-8372-14ab805815af', 'metadata': {'width': 640, 'height': 480, 'format': 'Jpeg'}}
# 0.9823791232241936
# 1.0062641276514108
# <Response [200]>
# {'objects': [{'rectangle': {'x': 199, 'y': 154, 'w': 215, 'h': 77}, 'object': 'Glasses', 'confidence': 0.837, 'parent': {'object': 'Personal care', 'confidence': 0.839}}, {'rectangle': {'x': 13, 'y': 18, 'w': 518, 'h': 462}, 'object': 'person', 'confidence': 0.866}], 'requestId': 'b742de8d-809f-45f2-b4a1-c2b3437ec24e', 'metadata': {'width': 640, 'height': 480, 'format': 'Jpeg'}}
# 0.9906976744186047
# 1.001930501930502
# <Response [200]>
# {'objects': [{'rectangle': {'x': 266, 'y': 219, 'w': 141, 'h': 47}, 'object': 'Glasses', 'confidence': 0.721, 'parent': {'object': 'Personal care', 'confidence': 0.722}}, {'rectangle': {'x': 108, 'y': 125, 'w': 424, 'h': 346}, 'object': 'person', 'confidence': 0.839}], 'requestId': '62ca5652-750e-4fd4-91ea-24510eda78cd', 'metadata': {'width': 640, 'height': 480, 'format': 'Jpeg'}}
# 2.498113776972989
# 1.6312847638782855
# <Response [200]>
# {'objects': [{'rectangle': {'x': 235, 'y': 277, 'w': 98, 'h': 27}, 'object': 'Glasses', 'confidence': 0.7, 'parent': {'object': 'Personal care', 'confidence': 0.701}}, {'rectangle': {'x': 130, 'y': 209, 'w': 298, 'h': 268}, 'object': 'person', 'confidence': 0.874}], 'requestId': 'aa608415-cd2a-48f9-98bf-322368bc5a0c', 'metadata': {'width': 640, 'height': 480, 'format': 'Jpeg'}}
# 2.50453514739229
# 1.8369227687068015
# <Response [200]>
# {'objects': [{'rectangle': {'x': 250, 'y': 280, 'w': 90, 'h': 29}, 'object': 'Glasses', 'confidence': 0.682, 'parent': {'object': 'Personal care', 'confidence': 0.682}}, {'rectangle': {'x': 146, 'y': 211, 'w': 273, 'h': 269}, 'object': 'person', 'confidence': 0.878}], 'requestId': 'b39de3cc-e98a-4804-98eb-d77ea08fb665', 'metadata': {'width': 640, 'height': 480, 'format': 'Jpeg'}}
# 1.013793103448276
# 1.087517191606411
# <Response [200]>
# {'objects': [{'rectangle': {'x': 248, 'y': 282, 'w': 93, 'h': 29}, 'object': 'Glasses', 'confidence': 0.678, 'parent': {'object': 'Personal care', 'confidence': 0.679}}, {'rectangle': {'x': 146, 'y': 212, 'w': 273, 'h': 268}, 'object': 'person', 'confidence': 0.875}], 'requestId': '8fe4843e-b760-4de3-a978-e91cd3ef1685', 'metadata': {'width': 640, 'height': 480, 'format': 'Jpeg'}}
# 0.967741935483871
# 1.0037313432835822
# <Response [200]>
# {'objects': [{'rectangle': {'x': 213, 'y': 208, 'w': 271, 'h': 96}, 'object': 'Glasses', 'confidence': 0.794, 'parent': {'object': 'Personal care', 'confidence': 0.795}}, {'rectangle': {'x': 5, 'y': 17, 'w': 529, 'h': 462}, 'object': 'person', 'confidence': 0.802}], 'requestId': '35ea1fa4-a578-428c-bfc8-5be50e0d9d40', 'metadata': {'width': 640, 'height': 480, 'format': 'Jpeg'}}
# 0.1036669741697417
# 0.2993641519161368
# <Response [200]>
# {'objects': [{'rectangle': {'x': 214, 'y': 210, 'w': 269, 'h': 94}, 'object': 'Glasses', 'confidence': 0.824, 'parent': {'object': 'Personal care', 'confidence': 0.826}}, {'rectangle': {'x': 484, 'y': 294, 'w': 149, 'h': 186}, 'object': 'person', 'confidence': 0.673}, {'rectangle': {'x': 6, 'y': 17, 'w': 525, 'h': 463}, 'object': 'person', 'confidence': 0.795}], 'requestId': '2b0d17ec-5832-4472-9880-5cfa3df18c93', 'metadata': {'width': 640, 'height': 480, 'format': 'Jpeg'}}
# 1.0288697302855334
# 8.818575449231435
# 1.0054427645788337
# <Response [200]>
# {'objects': [{'rectangle': {'x': 199, 'y': 204, 'w': 277, 'h': 101}, 'object': 'Glasses', 'confidence': 0.841, 'parent': {'object': 'Personal care', 'confidence': 0.843}}, {'rectangle': {'x': 493, 'y': 303, 'w': 134, 'h': 175}, 'object': 'person', 'confidence': 0.646}, {'rectangle': {'x': 5, 'y': 18, 'w': 526, 'h': 462}, 'object': 'person', 'confidence': 0.802}], 'requestId': 'fe425d4a-71b7-4917-a4e7-64aca2491d3b', 'metadata': {'width': 640, 'height': 480, 'format': 'Jpeg'}}
# 0.90381384708868
# 1.1818336886993603
# 0.1140437509258802
# 10.365671641791044
# 1.000259246456965
# <Response [200]>
# {'objects': [{'rectangle': {'x': 136, 'y': 174, 'w': 273, 'h': 87}, 'object': 'Glasses', 'confidence': 0.874, 'parent': {'object': 'Personal care', 'confidence': 0.874}}, {'rectangle': {'x': 484, 'y': 295, 'w': 150, 'h': 185}, 'object': 'person', 'confidence': 0.589}, {'rectangle': {'x': 4, 'y': 14, 'w': 538, 'h': 464}, 'object': 'person', 'confidence': 0.785}], 'requestId': '11e39086-f4c9-4e1f-8902-dcec532472e2', 'metadata': {'width': 640, 'height': 480, 'format': 'Jpeg'}}
# 1.1779293503431434
# 0.8450450450450451
# 0.0939382771439559
# 8.757189189189189
# 0.9734809639789771
# <Response [200]>
# {'objects': [{'rectangle': {'x': 160, 'y': 169, 'w': 265, 'h': 89}, 'object': 'Glasses', 'confidence': 0.853, 'parent': {'object': 'Personal care', 'confidence': 0.854}}, {'rectangle': {'x': 487, 'y': 318, 'w': 143, 'h': 162}, 'object': 'person', 'confidence': 0.776}, {'rectangle': {'x': 9, 'y': 14, 'w': 533, 'h': 465}, 'object': 'person', 'confidence': 0.899}], 'requestId': '96d093a6-1220-4b4b-b2f6-4ca7a368857f', 'metadata': {'width': 640, 'height': 480, 'format': 'Jpeg'}}
# 1.0070383718465126
# 1.1978761978761978
# 0.11196513950251165
# 10.775792109125442
# 1.0072101515059815
# <Response [200]>
# {'objects': [{'rectangle': {'x': 236, 'y': 124, 'w': 236, 'h': 84}, 'object': 'Glasses', 'confidence': 0.825, 'parent': {'object': 'Personal care', 'confidence': 0.826}}, {'rectangle': {'x': 490, 'y': 305, 'w': 145, 'h': 170}, 'object': 'person', 'confidence': 0.751}], 'requestId': 'ab171045-ba8f-49d5-8eb2-cc3f85d0eb37', 'metadata': {'width': 640, 'height': 480, 'format': 'Jpeg'}}
# 1.189719531880549
# 0.9397971602434078
# 10.054563894523326
# <Response [200]>
# {'objects': [{'rectangle': {'x': 192, 'y': 136, 'w': 234, 'h': 79}, 'object': 'Glasses', 'confidence': 0.829, 'parent': {'object': 'Personal care', 'confidence': 0.829}}, {'rectangle': {'x': 490, 'y': 310, 'w': 147, 'h': 167}, 'object': 'person', 'confidence': 0.805}, {'rectangle': {'x': 9, 'y': 14, 'w': 534, 'h': 466}, 'object': 'person', 'confidence': 0.773}], 'requestId': '609de9a6-8c98-4dc6-b8d3-4fb154e2547e', 'metadata': {'width': 640, 'height': 480, 'format': 'Jpeg'}}
# 1.0723790976955534
# 1.0041142205385147
# 0.09905804439729309
# <Response [200]>
# {'objects': [{'rectangle': {'x': 181, 'y': 137, 'w': 224, 'h': 76}, 'object': 'Glasses', 'confidence': 0.83, 'parent': {'object': 'Personal care', 'confidence': 0.832}}, {'rectangle': {'x': 489, 'y': 313, 'w': 140, 'h': 164}, 'object': 'person', 'confidence': 0.754}, {'rectangle': {'x': 9, 'y': 13, 'w': 534, 'h': 466}, 'object': 'person', 'confidence': 0.869}], 'requestId': 'e9b820ab-88e7-4a5a-8f49-887b48a11c5a', 'metadata': {'width': 640, 'height': 480, 'format': 'Jpeg'}}
# 1.0858787593984962
# 1.0692073170731706
# 0.09865216762308916
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-f2454abe6e36> in <module>
#      18                 if(object1['object']== object2['object'] and
#      19                         (object1['rectangle']['w'] * object1['rectangle']['h'])/(object2['rectangle']['w'] * object2['rectangle']['h']) < 0.9):
# ---> 20                     winsound.Beep(440, 1000)
#      21
#      22     y1 = y2
#
# KeyboardInterrupt:
